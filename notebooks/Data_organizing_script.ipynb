# %%
from pathlib import Path

# %%
our_files = Path("C:/Users/Admin/Desktop/Final Year Project/dataset")

# %%
print(our_files.is_dir())
# Out:
# False

# %%
print(our_files.parent)
# Out:
# C:/Users/Admin/Desktop/Final Year Project

# %%
for file in our_files.iterdir():

    # 1) Check if the file is a file
    if file.is_file() and file.stem != ".DS_Store":
        # 2) Create helpful variables
        directory = file.parent
        extension = file.suffix

        old_name = file.stem
        plastic_type = str(file)[60:63]
        new_file_name = str(file)[55:-4]
        new_file = f'{new_file_name}{extension}'
        
        new_path = our_files.joinpath(plastic_type)
    
        if not new_path.exists():
            new_path.mkdir()
            
        new_file_path = new_path.joinpath(new_file)
        
        file.replace(new_file_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## spliting the directory into train test and val

# %%
input_directory = "/content/drive/MyDrive/Final year Project/data"
output_directory = "/content/drive/MyDrive/Final year Project"

# %%
import splitfolders

splitfolders.ratio(input_directory, # The location of dataset
                   output= output_directory, # The output location
                   seed=42, # The number of seed
                   ratio=(0.78, 0.12, 0.10), # The ratio of splited dataset
                   group_prefix=None, # If your dataset contains more than one file like ".jpg", ".pdf", etc
                   move=False # If you choose to move, turn this into True
                   )
# Out:
# Copying files: 6487 files [04:52, 22.14 files/s]
