# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
import os
import torch
from torch.utils.data import Dataset, DataLoader, random_split

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

# %%
data_dir  = '/content/drive/MyDrive/Final year Project/dataset'

classes = os.listdir(data_dir)
print(classes)
# Out:
# ['plastic', 'metal', 'cardboard', 'glass', 'trash', 'paper', 'ps', 'pp', 'pet', 'pe-hd']

# %%
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

transformations = transforms.Compose([transforms.ToTensor()])

dataset = ImageFolder(data_dir, transform = transformations)

# %%
dataset[4000][0].size()
# Out:
# torch.Size([3, 1277, 1920])

# %%
train_data_dir  = '/content/drive/MyDrive/Final year Project/data/train'

classes = os.listdir(data_dir)
print(classes)
# Out:
# ['plastic', 'metal', 'cardboard', 'glass', 'trash', 'paper', 'ps', 'pp', 'pet', 'pe-hd']

# %%
len(classes)
# Out:
# 10

# %%
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

transformations = transforms.Compose([transforms.Resize((227, 227)), transforms.ToTensor()])

train_ds = ImageFolder(train_data_dir, transform = transformations)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-6023069b10e6> in <module>
#       4 transformations = transforms.Compose([transforms.Resize((227, 227)), transforms.ToTensor()])
#       5
# ----> 6 train_ds = ImageFolder(train_data_dir, transform = transformations)
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     308         is_valid_file: Optional[Callable[[str], bool]] = None,
#     309     ):
# --> 310         super().__init__(
#     311             root,
#     312             loader,
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     144         super().__init__(root, transform=transform, target_transform=target_transform)
#     145         classes, class_to_idx = self.find_classes(self.root)
# --> 146         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147
#     148         self.loader = loader
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     188             # is potentially overridden and thus could have a different logic.
#     189             raise ValueError("The class_to_idx parameter cannot be None.")
# --> 190         return make_dataset(directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file)
#     191
#     192     def find_classes(self, directory: str) -> Tuple[List[str], Dict[str, int]]:
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     101         if extensions is not None:
#     102             msg += f"Supported extensions are: {extensions if isinstance(extensions, str) else ', '.join(extensions)}"
# --> 103         raise FileNotFoundError(msg)
#     104
#     105     return instances
#
# FileNotFoundError: Found no valid file for the classes pet, pp. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
def show_img(img, label):
    print('Label: ', train_ds.classes[label], "("+str(label)+")")
    plt.imshow(img.permute(1, 2, 0))

# %%
img, label = train_ds[2222]
show_img(img, label)
